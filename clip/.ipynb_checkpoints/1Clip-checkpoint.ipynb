# %% [markdown]
# # 第一次尝试Clip
# ## 只针对gender和age（artifact和session不好编写prompt，而且也不是很特色化的信息）
# ## 只针对单个受试者
# ### 11.2第一次尝试编写代码

# %% [markdown]
# ## 第1步：导入、设置与辅助函数

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
import torch.nn.functional as F
import numpy as np
import pickle
import os
import time
import pandas as pd
import random
import math

def set_seed(seed):
    """设置所有随机种子以确保结果可复现"""
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    g = torch.Generator()
    g.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed(seed)
        torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
    return g

# --- 辅助模块: EEGNet的原始组件 (保持不变) ---
class SeparableConv2d(nn.Module):
    def __init__(self, in_channels, out_channels, kernel_size, bias=False):
        super(SeparableConv2d, self).__init__()
        self.depthwise = nn.Conv2d(in_channels, in_channels, kernel_size=kernel_size, 
                                     groups=in_channels, bias=bias, padding='same')
        self.pointwise = nn.Conv2d(in_channels, out_channels, 
                                     kernel_size=1, bias=bias)
    def forward(self, x):
        out = self.depthwise(x)
        out = self.pointwise(out)
        return out

# %% [markdown]
# ## 第2步：修改后的 BCI2aDataset

# %%
class BCI2aDataset(torch.utils.data.Dataset):
    """
    修改后的数据集类 (Dataset Class)
    - 提取受试者ID (0-8)
    - __getitem__ 只返回 (eeg_data, action_label, subject_id)
    """
    def __init__(
        self,
        data_path: str,  # 数据文件路径 (例如 "A01T.pkl")
    ):
        # --- 基础属性 ---
        # 从 "A01T.pkl" 中提取 "A01T"
        self.subjectName = os.path.splitext(os.path.basename(data_path))[0]
        # 从 "A01T" 中提取 "01"，转为整数 1，再减 1 得到索引 0
        self.subject_id = int(self.subjectName[1:3]) - 1

        # --- 加载预处理好的 Pickle 数据 ---
        with open(data_path, "rb") as f:
            sub_data = pickle.load(f)
            
        # --- 数据和标签的赋值 ---
        self.data = torch.from_numpy(sub_data['x']).type(torch.FloatTensor)
        # 标签 (y) 是 [1, 2, 3, 4], 我们需要 [0, 1, 2, 3]
        self.labels = torch.tensor(sub_data['y'], dtype=torch.long) - 1
            
    def __len__(self):
        # 返回数据集中样本的总数
        return len(self.labels)

    def __getitem__(self, i):
        # 根据索引 i 获取单个数据样本
        # 返回: EEG数据, 动作标签 (0-3), 受试者ID (0-8)
        return self.data[i], self.labels[i], self.subject_id

# %% [markdown]
# ## 第3步：修改后的 EEGNet（作为编码器）

# %%
class EEGNet_Encoder(nn.Module):
    """
    修改后的 EEGNet，作为 EEG 编码器。
    - 移除了 inputMeta 和 num_class
    - 移除了 fc1 (分类头)
    - forward 方法返回 flatten 后的 (B, 512) 特征向量
    """
    def __init__(self, no_spatial_filters, no_channels, no_temporal_filters, temporal_length_1, temporal_length_2, window_length, drop_out_ratio=0.50, pooling2=4, pooling3=8):
        super(EEGNet_Encoder, self).__init__()
        self.drop_out_ratio = drop_out_ratio
        
        # --- 第1层: 时间卷积 ---
        self.conv1 = nn.Conv2d(1, no_temporal_filters, (1, temporal_length_1), padding='same', bias=False)
        self.batchnorm1 = nn.BatchNorm2d(no_temporal_filters, False)
        
        # --- 第2层: 深度空间卷积 ---
        self.conv2 = nn.Conv2d(no_temporal_filters, no_temporal_filters * no_spatial_filters, (no_channels, 1),
                                 groups=no_temporal_filters, bias=False)
        self.batchnorm2 = nn.BatchNorm2d(no_temporal_filters * no_spatial_filters, False)
        self.pooling2 = nn.AvgPool2d(1, pooling2)
        self.dropout = nn.Dropout(self.drop_out_ratio) # Dropout层
        
        # --- 第3层: 可分离卷积 ---
        self.separableConv2 = SeparableConv2d(no_temporal_filters * no_spatial_filters,
                                              no_temporal_filters * no_spatial_filters, (1, temporal_length_2))
        self.batchnorm3 = nn.BatchNorm2d(no_temporal_filters * no_spatial_filters, False)
        self.pooling3 = nn.AvgPool2d((1, pooling3))
        
        # --- 辅助函数: 自动计算全连接层输入维度 ---
        # 我们仍然需要这个函数来确保知道输出维度是 512
        eeg_random = torch.randn(4, no_channels, window_length)
        self.fc_length = self.calc_fc_features(eeg_random)
        print(f"--- EEGNet 编码器初始化完成，输出特征维度: {self.fc_length} ---")

    def calc_fc_features(self, x,):
        # (这个辅助函数保持不变)
        self.eval()
        with torch.no_grad():
            x = torch.unsqueeze(x, 1)
            x = self.conv1(x)
            x = self.batchnorm1(x)
            x = self.conv2(x)
            B, FB, Ch, TL = x.shape
            x = torch.reshape(x, (B, FB * Ch, 1, TL))
            x = nn.functional.elu(self.batchnorm2(x))
            x = self.pooling2(x)
            x = self.dropout(x)
            x = self.separableConv2.forward(x)
            x = nn.functional.elu(self.batchnorm3(x))
            x = self.pooling3(x)
            x = self.dropout(x)
            x = torch.flatten(x, start_dim=1)
            return x.shape[-1]
            
    def forward(self, x):
        # --- 核心: 前向传播 ---
        x = torch.unsqueeze(x, 1)
        x = self.conv1(x)
        x = self.batchnorm1(x)
        
        x = self.conv2(x)
        B, FB, Ch, TL = x.shape
        x = torch.reshape(x, (B, FB * Ch, 1, TL))
        x = nn.functional.elu(self.batchnorm2(x))
        x = self.pooling2(x)
        x = self.dropout(x)

        x = self.separableConv2.forward(x)
        x = nn.functional.elu(self.batchnorm3(x))
        x = self.pooling3(x)
        x = self.dropout(x)
        
        # --- 返回特征 ---
        x = torch.flatten(x, start_dim=1) # (B, 512)
        return x

# %% [markdown]
# ## 第4步：新的投影头和CLIP主模型

# %%
class ProjectionHead(nn.Module):
    """
    按您要求设计的投影头 (决定 3-B):
    两层 MLP + GELU + 残差连接 + LayerNorm
    """
    def __init__(self, in_dim: int, out_dim: int = 256, hidden_dim: int = 1024):
        super().__init__()
        # 瓶颈层 (Bottleneck) 结构
        self.fc1 = nn.Linear(in_dim, hidden_dim)
        self.gelu = nn.GELU()
        self.fc2 = nn.Linear(hidden_dim, out_dim)
        
        # 残差连接 (如果输入输出维度不同，则使用一个线性层来匹配)
        if in_dim == out_dim:
            self.residual_proj = nn.Identity()
        else:
            self.residual_proj = nn.Linear(in_dim, out_dim, bias=False)
            
        self.norm = nn.LayerNorm(out_dim) # 最终的 LayerNorm

    def forward(self, x):
        # F(x)
        x_proj = self.fc2(self.gelu(self.fc1(x)))
        # residual(x)
        residual = self.residual_proj(x)
        
        # F(x) + residual(x), 然后 LayerNorm
        return self.norm(x_proj + residual)

class EEGClipModel(nn.Module):
    """
    将 EEG 编码器和文本原型/投影头组合在一起的 CLIP 主模型
    """
    def __init__(self, eeg_encoder, text_prototypes_tensor, eeg_dim=512, text_dim=1024, embed_dim=256):
        super().__init__()
        self.eeg_encoder = eeg_encoder
        
        # 投影头
        self.eeg_proj_head = ProjectionHead(in_dim=eeg_dim, out_dim=embed_dim)
        self.text_proj_head = ProjectionHead(in_dim=text_dim, out_dim=embed_dim)
        
        # 存储文本原型 (9个受试者 x 4个类别 x 1024维)
        # 注册为 'buffer'，它不会被训练，但会随模型一起保存和移动到 .to(device)
        self.register_buffer("text_prototypes", text_prototypes_tensor)
        # --- 可学习的温度参数（以 logit_scale 形式存储） ---
        # 与 temperature=0.07 等价的初始化：logit_scale = log(1/0.07)
        self.logit_scale = nn.Parameter(torch.log(torch.tensor(1.0 / 0.05)))

    def get_temperature(self):
        # τ = 1 / exp(logit_scale)
        return torch.exp(-self.logit_scale)

    def get_logit_scale(self):
        # s = exp(logit_scale)
        return torch.exp(self.logit_scale)

    def encode_eeg(self, eeg_data):
        """编码EEG数据: EEGNet -> ProjHead"""
        eeg_features = self.eeg_encoder(eeg_data) # (B, 512)
        eeg_embeds = self.eeg_proj_head(eeg_features) # (B, 256)
        return eeg_embeds

    def encode_text(self):
        """编码文本原型: Prototypes -> ProjHead"""
        # (9, 4, 1024) -> (36, 1024)
        prototypes_flat = self.text_prototypes.view(-1, self.text_prototypes.shape[-1])
        
        # (36, 1024) -> (36, 256)
        text_embeds = self.text_proj_head(prototypes_flat)
        
        # (36, 256) -> (9, 4, 256)
        text_embeds_grouped = text_embeds.view(
            self.text_prototypes.shape[0],
            self.text_prototypes.shape[1],
            -1
        )
        return text_embeds_grouped

    def forward(self, eeg_data):
        """
        前向传播: 同时编码 EEG 和 文本
        """
        eeg_embeds = self.encode_eeg(eeg_data)    # (B, 256)
        text_embeds = self.encode_text()         # (9, 4, 256)
        return eeg_embeds, text_embeds

# %% [markdown]
# ## 第5步：加载原型和CLIP损失函数

# %%
def load_prototypes(prototype_dir, subjects=9, classes=None):
    """
    加载所有 36 个 .pt 原型文件
    """
    if classes is None:
        classes = ["left_hand", "right_hand", "feet", "tongue"]
    
    all_prototypes = []
    print(f"--- 正在从 {prototype_dir} 加载原型... ---")
    
    for s_id in range(1, subjects + 1): # 循环 S01 到 S09
        subject_prototypes = []
        for cls in classes: # 循环 4 个类别
            file_name = f"S{s_id:02d}_{cls}.pt"
            file_path = os.path.join(prototype_dir, file_name)
            
            try:
                tensor = torch.load(file_path, map_location='cpu')
                subject_prototypes.append(tensor)
            except FileNotFoundError:
                print(f"错误: 找不到文件 {file_path}")
                return None
        
        # (4, 1024)
        all_prototypes.append(torch.stack(subject_prototypes))
        
    # (9, 4, 1024)
    final_tensor = torch.stack(all_prototypes)
    print(f"原型加载成功! 最终张量维度: {final_tensor.shape}")
    return final_tensor

def clip_loss(eeg_embeds, text_embeds_grouped, eeg_labels, eeg_subject_ids, logit_scale):

    """
    计算CLIP对比损失 (InfoNCE)
    eeg_embeds: (B, 256) - 当前批次的EEG嵌入
    text_embeds_grouped: (9, 4, 256) - *所有*受试者的文本嵌入
    eeg_labels: (B,) - 动作标签 (0-3)
    eeg_subject_ids: (B,) - 受试者ID (0-8)
    """
    
    # 1. 归一化 (L2 Norm)，这是计算余弦相似度的关键
    eeg_embeds = F.normalize(eeg_embeds, p=2, dim=-1)
    text_embeds_grouped = F.normalize(text_embeds_grouped, p=2, dim=-1)

    # 2 将 logit_scale 安全地指数化为缩放因子（等价于 1/temperature）
    #    也可以做个clamp，避免数值过大/过小导致训练不稳
    scale = torch.exp(torch.clamp(logit_scale, min=-5.0, max=5.0))   # exp([-5,5])≈[0.0067,148]

    
    total_loss = 0.0
    
    # 遍历批次中的每一个样本
    for i in range(eeg_embeds.shape[0]):
        eeg_vec = eeg_embeds[i]           # (256,)
        action_label = eeg_labels[i]      # e.g., 2 (feet)
        subject_id = eeg_subject_ids[i]   # e.g., 0 (S01)
        
        # 2. 提取当前受试者对应的 4 个文本原型
        # (4, 256)
        subject_text_embeds = text_embeds_grouped[subject_id]
        
        # 3. 计算余弦相似度
        # (256,) @ (256, 4) -> (4,)
        # 这会得到EEG向量与该受试者4个动作原型的相似度分数
        sim_scores = eeg_vec @ subject_text_embeds.T
        
        # 4. 计算对比损失 (InfoNCE)
        # 这本质上就是一个标准的交叉熵损失
        # 我们希望模型在 4 个选项中，正确预测 'action_label'
        # 我们添加一个温度系数 (temperature) 来缩放 logits，这是CLIP的标准做法
        logits = sim_scores * scale
        loss = F.cross_entropy(logits, action_label)
        
        total_loss += loss

    return total_loss / eeg_embeds.shape[0] # 返回批次平均损失

# %% [markdown]
# ## 第6步：训练与评估函数

# %%
def run_epoch_clip(model, loader, optimizer, criterion, device, all_prototypes_tensor):
    """
    CLIP 训练函数
    """
    model.train() # 设置为训练模式
    total_loss = 0.0
    
    for eeg_data, action_labels, subject_ids in loader:
        # 将所有数据移动到GPU
        eeg_data = eeg_data.to(device)
        action_labels = action_labels.to(device)
        subject_ids = subject_ids.to(device)
        
        optimizer.zero_grad()
        
        # --- 前向传播 ---
        # (B, 256)      (9, 4, 256)
        eeg_embeds, text_embeds_grouped = model(eeg_data)
        
        # --- 计算损失 ---
        loss = criterion(eeg_embeds, text_embeds_grouped, action_labels, subject_ids, model.logit_scale)
        
        # --- 反向传播 ---
        loss.backward()
        optimizer.step()
        
        total_loss += loss.item() * eeg_data.size(0)
        
    return total_loss / len(loader.dataset)

def evaluate_clip(model, loader, criterion, device, all_prototypes_tensor):
    """
    CLIP 评估函数
    评估方式: 检查EEG嵌入是否与 '正确' 的文本原型最接近
    """
    model.eval() # 设置为评估模式
    total_loss = 0.0
    total_correct = 0
    
    with torch.no_grad(): # 评估时不需要计算梯度
        # (9, 4, 1024) -> (9, 4, 256)
        # 预先计算所有36个文本嵌入
        text_embeds_grouped = model.encode_text()
        
        for eeg_data, action_labels, subject_ids in loader:
            eeg_data = eeg_data.to(device)
            action_labels = action_labels.to(device)
            subject_ids = subject_ids.to(device)
            
            # (B, 512) -> (B, 256)
            eeg_embeds = model.encode_eeg(eeg_data)
            
            # --- 计算损失 (可选, 但有助于监控) ---
            loss = criterion(eeg_embeds, text_embeds_grouped, action_labels, subject_ids, model.logit_scale)

            total_loss += loss.item() * eeg_data.size(0)

            # --- 计算准确率 ---
            # 归一化
            eeg_embeds = F.normalize(eeg_embeds, p=2, dim=-1)
            text_embeds_grouped_norm = F.normalize(text_embeds_grouped, p=2, dim=-1)
            
            for i in range(eeg_data.shape[0]):
                eeg_vec = eeg_embeds[i]
                true_label = action_labels[i]
                subject_id = subject_ids[i]
                
                # 提取该受试者的 4 个原型 (4, 256)
                subject_text_embeds = text_embeds_grouped_norm[subject_id]
                
                # 计算余弦相似度 (4,)
                sim_scores = eeg_vec @ subject_text_embeds.T
                
                # 找到最相似的原型的索引
                pred_label = sim_scores.argmax()
                
                if pred_label == true_label:
                    total_correct += 1

    avg_loss = total_loss / len(loader.dataset)
    accuracy = total_correct / len(loader.dataset)
    return avg_loss, accuracy

# %% [markdown]
# ## 第7步：主执行程序（训练循环）

# %%
# --- 1. 设置参数 ---
SEED_VALUE = 42
PROTOTYPE_DIR = "/data/leuven/379/vsc37996/test/textCoder/subject_prototypes" # [!!!] 确认这是您的 .pt 文件夹路径
TRAIN_DATA_PATH = "/lustre1/project/stg_00160/EEG_LLM/A01T.pkl"             # [!!!] 确认这是A01的训练数据
TEST_DATA_PATH = "/lustre1/project/stg_00160/EEG_LLM/A01E.pkl"              # [!!!] 确认这是A01的测试数据
EEG_DIM = 512    # EEGNet的输出
TEXT_DIM = 1024  # Qwen 向量的维度
EMBED_DIM = 256  # 统一的嵌入空间维度

# --- 训练超参数 ---
batch_size = 32
epochs = 100
lr = 1e-4 # CLIP 训练通常使用较小的学习率
weight_decay = 1e-4

# --- 2. 准备工作 ---
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
data_loader_generator = set_seed(SEED_VALUE)
print(f"--- 正在 {device} 上运行 ---")

# --- 3. 加载数据 ---
# 加载 36 个文本原型 (9, 4, 1024)
all_prototypes_tensor = load_prototypes(PROTOTYPE_DIR).to(device)

# 实例化数据集 (只加载受试者A01)
# [!!!] 注意: 这个训练只适用于受试者A01, 因为数据集类是为A01硬编码的
# (BCI2aDataset 会自动从 "A01T.pkl" 解析出 subject_id=0)
train_dataset = BCI2aDataset(data_path=TRAIN_DATA_PATH)
test_dataset = BCI2aDataset(data_path=TEST_DATA_PATH)

print(f"训练数据: {len(train_dataset)} 样本, 受试者ID: {train_dataset.subject_id}")
print(f"测试数据: {len(test_dataset)} 样本, 受试者ID: {test_dataset.subject_id}")

# 实例化数据加载器
train_loader = DataLoader(
    train_dataset, batch_size=batch_size, shuffle=True,
    num_workers=0, pin_memory=True, drop_last=True, # drop_last=True 有助于稳定训练
    generator=data_loader_generator
)
test_loader = DataLoader(
    test_dataset, batch_size=batch_size, shuffle=False,
    num_workers=0, pin_memory=True, drop_last=False
)

# --- 4. 实例化模型和优化器 ---
# 实例化 EEG 编码器
eeg_encoder = EEGNet_Encoder(
    no_spatial_filters=4, no_channels=22, no_temporal_filters=8,
    temporal_length_1=64, temporal_length_2=16, 
    window_length=int(4*128), # 512
    drop_out_ratio=0.5
)

# 实例化 CLIP 主模型
model = EEGClipModel(
    eeg_encoder=eeg_encoder,
    text_prototypes_tensor=all_prototypes_tensor,
    eeg_dim=EEG_DIM,
    text_dim=TEXT_DIM,
    embed_dim=EMBED_DIM
).to(device)

# 定义损失函数和优化器
criterion = clip_loss # 使用我们自定义的损失函数
optimizer = optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)

# --- 5. 开始训练 ---
best_test_acc = 0.0
print(f"\n--- 开始 CLIP 训练 (共 {epochs} 轮) ---")

history = {
    "epoch": [],"train_loss": [],"test_loss": [],
    "test_acc": [],        # 存 0~1 之间的小数
    "tau": [],             # 温度（如果你做成了可学习温度）
    "logit_scale": []      # s = 1/tau
}

# ====== 训练循环内：在 print 之前，追加记录 ======
for epoch in range(1, epochs + 1):
    train_loss = run_epoch_clip(model, train_loader, optimizer, criterion, device, all_prototypes_tensor)
    test_loss, test_acc = evaluate_clip(model, test_loader, criterion, device, all_prototypes_tensor)

    # 记录温度（若没有可学习温度，可把 tau/logit_scale 留空或删除）
    with torch.no_grad():
        try:
            cur_tau = model.get_temperature().item()
            cur_s   = model.get_logit_scale().item()
        except AttributeError:
            cur_tau, cur_s = float("nan"), float("nan")

    # 追加到历史
    history["epoch"].append(epoch)
    history["train_loss"].append(float(train_loss))
    history["test_loss"].append(float(test_loss))
    history["test_acc"].append(float(test_acc))
    history["tau"].append(cur_tau)
    history["logit_scale"].append(cur_s)

    # （你原来的打印保留）
    if test_acc > best_test_acc:
        best_test_acc = test_acc

    if epoch % 10 == 0 or epoch == 1:
        print(f"[epoch {epoch}] temperature τ={cur_tau:.5f}, logit_scale s={cur_s:.5f}")

    print(
        f"Epoch {epoch:03d} | "
        f"train_loss: {train_loss:.4f} | "
        f"test_loss: {test_loss:.4f}   test_acc: {test_acc*100:.2f}%"
    )

print(f"\n--- 训练完成 ---")
print(f"最佳测试准确率 (CLIP): {best_test_acc*100:.2f}%")

# ====== 训练后：新增 —— 导出 CSV（下个 cell 读这个文件画图）======
import pandas as pd
history_df = pd.DataFrame(history)
history_df.to_csv("clip_training_history.csv", index=False)
print("已保存训练曲线到 clip_training_history.csv")
# Out:
# --- 正在 cuda 上运行 ---
# --- 正在从 /data/leuven/379/vsc37996/test/textCoder/subject_prototypes 加载原型... ---
# 原型加载成功! 最终张量维度: torch.Size([9, 4, 1024])
# 训练数据: 288 样本, 受试者ID: 0
# 测试数据: 288 样本, 受试者ID: 0
# --- EEGNet 编码器初始化完成，输出特征维度: 512 ---
# /data/leuven/379/vsc37996/miniconda3/envs/test1/lib/python3.11/site-packages/torch/nn/modules/conv.py:543: UserWarning: Using padding='same' with even kernel lengths and odd dilation may require a zero-padded copy of the input be created (Triggered internally at /pytorch/aten/src/ATen/native/Convolution.cpp:1027.)
#   return F.conv2d(
# --- 开始 CLIP 训练 (共 100 轮) ---
# [epoch 1] temperature τ=0.10003, logit_scale s=9.99747
# Epoch 001 | train_loss: 1.3838 | test_loss: 1.3207   test_acc: 41.32%
# Epoch 002 | train_loss: 1.3326 | test_loss: 1.2845   test_acc: 43.75%
# Epoch 003 | train_loss: 1.2804 | test_loss: 1.2481   test_acc: 46.18%
# Epoch 004 | train_loss: 1.1919 | test_loss: 1.2985   test_acc: 46.53%
# Epoch 005 | train_loss: 1.1538 | test_loss: 1.2846   test_acc: 44.44%
# Epoch 006 | train_loss: 1.1173 | test_loss: 1.2659   test_acc: 44.79%
# Epoch 007 | train_loss: 1.0998 | test_loss: 1.2950   test_acc: 46.18%
# Epoch 008 | train_loss: 1.1004 | test_loss: 1.3299   test_acc: 44.10%
# Epoch 009 | train_loss: 1.0697 | test_loss: 1.3606   test_acc: 42.36%
# [epoch 10] temperature τ=0.09973, logit_scale s=10.02698
# Epoch 010 | train_loss: 1.0693 | test_loss: 1.3490   test_acc: 42.71%
# Epoch 011 | train_loss: 1.0316 | test_loss: 1.3614   test_acc: 44.44%
# Epoch 012 | train_loss: 1.0543 | test_loss: 1.3791   test_acc: 45.14%
# Epoch 013 | train_loss: 0.9818 | test_loss: 1.3694   test_acc: 45.83%
# Epoch 014 | train_loss: 0.9986 | test_loss: 1.3786   test_acc: 46.53%
# Epoch 015 | train_loss: 0.9969 | test_loss: 1.3516   test_acc: 47.57%
# Epoch 016 | train_loss: 1.0062 | test_loss: 1.2885   test_acc: 49.65%
# Epoch 017 | train_loss: 0.9569 | test_loss: 1.3250   test_acc: 49.31%
# Epoch 018 | train_loss: 0.9149 | test_loss: 1.3444   test_acc: 47.22%
# Epoch 019 | train_loss: 0.9144 | test_loss: 1.4049   test_acc: 44.10%
# [epoch 20] temperature τ=0.09956, logit_scale s=10.04429
# Epoch 020 | train_loss: 0.8618 | test_loss: 1.3988   test_acc: 48.26%
# Epoch 021 | train_loss: 0.9008 | test_loss: 1.3445   test_acc: 49.31%
# Epoch 022 | train_loss: 0.9092 | test_loss: 1.2743   test_acc: 49.31%
# Epoch 023 | train_loss: 0.9124 | test_loss: 1.2462   test_acc: 48.61%
# Epoch 024 | train_loss: 0.9151 | test_loss: 1.2424   test_acc: 49.31%
# Epoch 025 | train_loss: 0.8878 | test_loss: 1.3071   test_acc: 48.26%
# Epoch 026 | train_loss: 0.9138 | test_loss: 1.2817   test_acc: 50.35%
# Epoch 027 | train_loss: 0.8675 | test_loss: 1.2816   test_acc: 48.96%
# Epoch 028 | train_loss: 0.8456 | test_loss: 1.2663   test_acc: 48.96%
# Epoch 029 | train_loss: 0.7919 | test_loss: 1.2802   test_acc: 51.39%
# [epoch 30] temperature τ=0.09937, logit_scale s=10.06384
# Epoch 030 | train_loss: 0.8230 | test_loss: 1.3245   test_acc: 51.39%
# Epoch 031 | train_loss: 0.8116 | test_loss: 1.3016   test_acc: 51.04%
# Epoch 032 | train_loss: 0.7979 | test_loss: 1.2780   test_acc: 50.69%
# Epoch 033 | train_loss: 0.7477 | test_loss: 1.2973   test_acc: 53.47%
# Epoch 034 | train_loss: 0.7898 | test_loss: 1.3093   test_acc: 50.69%
# Epoch 035 | train_loss: 0.7616 | test_loss: 1.3170   test_acc: 51.74%
# Epoch 036 | train_loss: 0.8453 | test_loss: 1.2758   test_acc: 51.74%
# Epoch 037 | train_loss: 0.7862 | test_loss: 1.2709   test_acc: 52.78%
# Epoch 038 | train_loss: 0.6621 | test_loss: 1.3859   test_acc: 51.39%
# Epoch 039 | train_loss: 0.7150 | test_loss: 1.3269   test_acc: 54.51%
# [epoch 40] temperature τ=0.09928, logit_scale s=10.07248
# Epoch 040 | train_loss: 0.7720 | test_loss: 1.2710   test_acc: 54.51%
# Epoch 041 | train_loss: 0.7358 | test_loss: 1.2860   test_acc: 54.51%
# Epoch 042 | train_loss: 0.6980 | test_loss: 1.3083   test_acc: 54.51%
# Epoch 043 | train_loss: 0.6544 | test_loss: 1.3185   test_acc: 55.90%
# Epoch 044 | train_loss: 0.7164 | test_loss: 1.3176   test_acc: 55.90%
# Epoch 045 | train_loss: 0.6824 | test_loss: 1.2928   test_acc: 55.56%
# Epoch 046 | train_loss: 0.6923 | test_loss: 1.3003   test_acc: 57.29%
# Epoch 047 | train_loss: 0.7326 | test_loss: 1.2586   test_acc: 57.29%
# Epoch 048 | train_loss: 0.5781 | test_loss: 1.2614   test_acc: 59.38%
# Epoch 049 | train_loss: 0.6553 | test_loss: 1.2978   test_acc: 58.68%
# [epoch 50] temperature τ=0.09911, logit_scale s=10.08940
# Epoch 050 | train_loss: 0.7539 | test_loss: 1.2958   test_acc: 57.99%
# Epoch 051 | train_loss: 0.6888 | test_loss: 1.1726   test_acc: 60.42%
# Epoch 052 | train_loss: 0.6931 | test_loss: 1.1964   test_acc: 59.38%
# Epoch 053 | train_loss: 0.6517 | test_loss: 1.2339   test_acc: 59.72%
# Epoch 054 | train_loss: 0.7295 | test_loss: 1.1796   test_acc: 59.38%
# Epoch 055 | train_loss: 0.6167 | test_loss: 1.1996   test_acc: 58.68%
# Epoch 056 | train_loss: 0.6215 | test_loss: 1.2532   test_acc: 60.07%
# Epoch 057 | train_loss: 0.5449 | test_loss: 1.3192   test_acc: 58.68%
# Epoch 058 | train_loss: 0.6152 | test_loss: 1.3240   test_acc: 59.72%
# Epoch 059 | train_loss: 0.6782 | test_loss: 1.2521   test_acc: 59.38%
# [epoch 60] temperature τ=0.09905, logit_scale s=10.09554
# Epoch 060 | train_loss: 0.6400 | test_loss: 1.2164   test_acc: 59.38%
# Epoch 061 | train_loss: 0.5801 | test_loss: 1.2331   test_acc: 59.38%
# Epoch 062 | train_loss: 0.6223 | test_loss: 1.2267   test_acc: 58.68%
# Epoch 063 | train_loss: 0.6513 | test_loss: 1.2189   test_acc: 59.03%
# Epoch 064 | train_loss: 0.6334 | test_loss: 1.1669   test_acc: 59.72%
# Epoch 065 | train_loss: 0.5523 | test_loss: 1.1694   test_acc: 59.03%
# Epoch 066 | train_loss: 0.5943 | test_loss: 1.1969   test_acc: 58.33%
# Epoch 067 | train_loss: 0.6307 | test_loss: 1.2038   test_acc: 61.46%
# Epoch 068 | train_loss: 0.5750 | test_loss: 1.2447   test_acc: 57.64%
# Epoch 069 | train_loss: 0.5396 | test_loss: 1.2196   test_acc: 59.72%
# [epoch 70] temperature τ=0.09894, logit_scale s=10.10693
# Epoch 070 | train_loss: 0.6479 | test_loss: 1.1657   test_acc: 62.85%
# Epoch 071 | train_loss: 0.5166 | test_loss: 1.2639   test_acc: 60.07%
# Epoch 072 | train_loss: 0.5831 | test_loss: 1.2158   test_acc: 60.42%
# Epoch 073 | train_loss: 0.5398 | test_loss: 1.2033   test_acc: 60.07%
# Epoch 074 | train_loss: 0.6119 | test_loss: 1.2333   test_acc: 61.81%
# Epoch 075 | train_loss: 0.5520 | test_loss: 1.1924   test_acc: 61.81%
# Epoch 076 | train_loss: 0.5766 | test_loss: 1.1761   test_acc: 59.38%
# Epoch 077 | train_loss: 0.5422 | test_loss: 1.1699   test_acc: 60.42%
# Epoch 078 | train_loss: 0.5686 | test_loss: 1.2257   test_acc: 59.38%
# Epoch 079 | train_loss: 0.5273 | test_loss: 1.2467   test_acc: 57.99%
# [epoch 80] temperature τ=0.09872, logit_scale s=10.12944
# Epoch 080 | train_loss: 0.5540 | test_loss: 1.2697   test_acc: 58.33%
# Epoch 081 | train_loss: 0.5288 | test_loss: 1.2266   test_acc: 58.33%
# Epoch 082 | train_loss: 0.5339 | test_loss: 1.2116   test_acc: 60.76%
# Epoch 083 | train_loss: 0.4937 | test_loss: 1.2458   test_acc: 57.99%
# Epoch 084 | train_loss: 0.5360 | test_loss: 1.2095   test_acc: 60.42%
# Epoch 085 | train_loss: 0.4941 | test_loss: 1.1922   test_acc: 61.11%
# Epoch 086 | train_loss: 0.5363 | test_loss: 1.2378   test_acc: 59.72%
# Epoch 087 | train_loss: 0.5755 | test_loss: 1.2395   test_acc: 60.42%
# Epoch 088 | train_loss: 0.4559 | test_loss: 1.1886   test_acc: 61.46%
# Epoch 089 | train_loss: 0.4930 | test_loss: 1.2162   test_acc: 62.50%
# [epoch 90] temperature τ=0.09853, logit_scale s=10.14950
# Epoch 090 | train_loss: 0.4651 | test_loss: 1.2683   test_acc: 61.46%
# Epoch 091 | train_loss: 0.4815 | test_loss: 1.2565   test_acc: 61.46%
# Epoch 092 | train_loss: 0.4372 | test_loss: 1.2494   test_acc: 61.46%
# Epoch 093 | train_loss: 0.5141 | test_loss: 1.3115   test_acc: 61.46%
# Epoch 094 | train_loss: 0.5300 | test_loss: 1.2866   test_acc: 60.76%
# Epoch 095 | train_loss: 0.4762 | test_loss: 1.2435   test_acc: 61.81%
# Epoch 096 | train_loss: 0.4047 | test_loss: 1.2542   test_acc: 59.38%
# Epoch 097 | train_loss: 0.4296 | test_loss: 1.3257   test_acc: 58.33%
# Epoch 098 | train_loss: 0.4770 | test_loss: 1.2704   test_acc: 61.46%
# Epoch 099 | train_loss: 0.4072 | test_loss: 1.3244   test_acc: 60.76%
# [epoch 100] temperature τ=0.09831, logit_scale s=10.17148
# Epoch 100 | train_loss: 0.4846 | test_loss: 1.3812   test_acc: 58.68%
#
# --- 训练完成 ---
# 最佳测试准确率 (CLIP): 62.85%
# 已保存训练曲线到 clip_training_history.csv

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# 读取训练历史
df = pd.read_csv("clip_training_history.csv")

def smooth(y, k=5):
    if k <= 1:
        return y
    # 简单移动平均平滑
    kernel = np.ones(k) / k
    # 边界用 nearest 方式扩展
    pad = k // 2
    y_pad = np.pad(y, (pad, pad), mode='edge')
    y_smooth = np.convolve(y_pad, kernel, mode='valid')
    return y_smooth

# 你可以调节平滑窗口，比如 k=1 表示不平滑
k = 3

# 1) Loss 曲线
plt.figure(figsize=(7,4.5))
plt.plot(df["epoch"], smooth(df["train_loss"].values, k), label="Train Loss")
plt.plot(df["epoch"], smooth(df["test_loss"].values,  k), label="Test Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("EEG-Text CLIP Training/Validation Loss")
plt.grid(True, alpha=0.3)
plt.legend()
plt.tight_layout()
plt.show()

# 2) Accuracy 曲线（转成百分比显示更直观）
plt.figure(figsize=(7,4.5))
plt.plot(df["epoch"], smooth((df["test_acc"].values*100), k), label="Test Acc (%)")
plt.xlabel("Epoch")
plt.ylabel("Accuracy (%)")
plt.title("EEG-Text CLIP Test Accuracy")
plt.grid(True, alpha=0.3)
plt.legend()
plt.tight_layout()
plt.show()

# 3) 可学习温度/缩放因子（如未启用可学习温度，会是 NaN）
if "tau" in df.columns and np.isfinite(df["tau"]).any():
    fig, ax1 = plt.subplots(figsize=(7,4.5))
    ax1.plot(df["epoch"], smooth(df["tau"].values, k), label="Temperature τ")
    ax1.set_xlabel("Epoch")
    ax1.set_ylabel("τ")
    ax1.grid(True, alpha=0.3)
    ax1.set_title("Learned Temperature (τ)")
    plt.tight_layout()
    plt.show()

if "logit_scale" in df.columns and np.isfinite(df["logit_scale"]).any():
    plt.figure(figsize=(7,4.5))
    plt.plot(df["epoch"], smooth(df["logit_scale"].values, k), label="logit_scale (= 1/τ)")
    plt.xlabel("Epoch")
    plt.ylabel("logit_scale")
    plt.title("Learned Logit Scale (1/τ)")
    plt.grid(True, alpha=0.3)
    plt.legend()
    plt.tight_layout()
    plt.show()
